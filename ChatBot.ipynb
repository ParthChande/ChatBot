# %%
import json
import numpy as np
import random
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD

nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

# Load intents file
with open('intents.json') as file:
    intents = json.load(file)

words = []
classes = []
documents = []
ignore_words = ['?', '!', '.']

# Preprocess data
for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training, dtype=object)

train_x = np.array(list(training[:, 0]), dtype=np.float32)
train_y = np.array(list(training[:, 1]), dtype=np.float32)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\parth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\parth\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])
model.summary()
history = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5')
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 128)               7936
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 10)                650
#
# =================================================================
# Total params: 16,842
# Trainable params: 16,842
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7/7 [==============================] - 2s 8ms/step - loss: 2.3571 - accuracy: 0.1714
# Epoch 2/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3850 - accuracy: 0.0286
# Epoch 3/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.2769 - accuracy: 0.1429
# Epoch 4/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1937 - accuracy: 0.1714
# Epoch 5/200
# 7/7 [==============================] - 0s 3ms/step - loss: 2.1386 - accuracy: 0.2857
# Epoch 6/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.2259 - accuracy: 0.2000
# Epoch 7/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.1115 - accuracy: 0.2286
# Epoch 8/200
# 7/7 [==============================] - 0s 4ms/step - loss: 2.0355 - accuracy: 0.4000
# Epoch 9/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9701 - accuracy: 0.4286
# Epoch 10/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.9083 - accuracy: 0.4286
# Epoch 11/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.8527 - accuracy: 0.4857
# Epoch 12/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.8685 - accuracy: 0.4000
# Epoch 13/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.6600 - accuracy: 0.5143
# Epoch 14/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.6888 - accuracy: 0.4857
# Epoch 15/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.5626 - accuracy: 0.5429
# Epoch 16/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3522 - accuracy: 0.8000
# Epoch 17/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.4304 - accuracy: 0.6286
# Epoch 18/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3043 - accuracy: 0.6000
# Epoch 19/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.3762 - accuracy: 0.6571
# Epoch 20/200
# 7/7 [==============================] - 0s 3ms/step - loss: 1.3661 - accuracy: 0.6286
# Epoch 21/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.1436 - accuracy: 0.8286
# Epoch 22/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.2134 - accuracy: 0.6286
# Epoch 23/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1679 - accuracy: 0.7143
# Epoch 24/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.9575 - accuracy: 0.8000
# Epoch 25/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8843 - accuracy: 0.7714
# Epoch 26/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.8011 - accuracy: 0.8571
# Epoch 27/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7278 - accuracy: 0.8571
# Epoch 28/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8493 - accuracy: 0.7714
# Epoch 29/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7766 - accuracy: 0.7429
# Epoch 30/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7944 - accuracy: 0.7143
# Epoch 31/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7473 - accuracy: 0.8571
# Epoch 32/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4769 - accuracy: 0.8571
# Epoch 33/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.7401 - accuracy: 0.8000
# Epoch 34/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6062 - accuracy: 0.8571
# Epoch 35/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7796 - accuracy: 0.7143
# Epoch 36/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4761 - accuracy: 0.8857
# Epoch 37/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4389 - accuracy: 0.8857
# Epoch 38/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3990 - accuracy: 0.8857
# Epoch 39/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5280 - accuracy: 0.8286
# Epoch 40/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4859 - accuracy: 0.9143
# Epoch 41/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6471 - accuracy: 0.7714
# Epoch 42/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3559 - accuracy: 0.9714
# Epoch 43/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.5091 - accuracy: 0.8571
# Epoch 44/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2301 - accuracy: 1.0000
# Epoch 45/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3266 - accuracy: 0.9143
# Epoch 46/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3630 - accuracy: 0.9429
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.3062 - accuracy: 0.8857
# Epoch 48/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.3431 - accuracy: 0.8857
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2308 - accuracy: 0.9714
# Epoch 50/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.4373 - accuracy: 0.8857
# Epoch 51/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.2560 - accuracy: 0.9714
# Epoch 52/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3400 - accuracy: 0.9429
# Epoch 53/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3440 - accuracy: 0.8571
# Epoch 54/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0750 - accuracy: 1.0000
# Epoch 55/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2890 - accuracy: 0.9429
# Epoch 56/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1656 - accuracy: 1.0000
# Epoch 57/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3265 - accuracy: 0.8857
# Epoch 58/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2100 - accuracy: 0.9429
# Epoch 59/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2978 - accuracy: 0.9143
# Epoch 60/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.2227 - accuracy: 0.9429
# Epoch 61/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.2005 - accuracy: 0.9714
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.1459 - accuracy: 1.0000
# Epoch 63/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2426 - accuracy: 0.9143
# Epoch 64/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2342 - accuracy: 0.9143
# Epoch 65/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.1165 - accuracy: 1.0000
# Epoch 66/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2029 - accuracy: 0.9429
# Epoch 67/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1401 - accuracy: 1.0000
# Epoch 68/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2374 - accuracy: 0.9143
# Epoch 69/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 70/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0726 - accuracy: 0.9714
# Epoch 71/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1008 - accuracy: 0.9714
# Epoch 72/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1335 - accuracy: 1.0000
# Epoch 73/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3303 - accuracy: 0.8857
# Epoch 74/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1156 - accuracy: 0.9714
# Epoch 75/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1206 - accuracy: 0.9714
# Epoch 76/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1257 - accuracy: 0.9714
# Epoch 77/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1361 - accuracy: 0.9714
# Epoch 78/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1046 - accuracy: 0.9714
# Epoch 79/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1765 - accuracy: 0.9714
# Epoch 80/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1026 - accuracy: 0.9429
# Epoch 81/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0656 - accuracy: 1.0000
# Epoch 82/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1129 - accuracy: 0.9714
# Epoch 83/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1104 - accuracy: 1.0000
# Epoch 84/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0967 - accuracy: 1.0000
# Epoch 85/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1708 - accuracy: 0.9143
# Epoch 86/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1360 - accuracy: 0.9429
# Epoch 87/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0945 - accuracy: 1.0000
# Epoch 88/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0453 - accuracy: 1.0000
# Epoch 89/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 90/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0587 - accuracy: 1.0000
# Epoch 91/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.0666 - accuracy: 1.0000
# Epoch 92/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1312 - accuracy: 0.9429
# Epoch 93/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0974 - accuracy: 0.9714
# Epoch 94/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1337 - accuracy: 0.9714
# Epoch 95/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0692 - accuracy: 1.0000
# Epoch 96/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0732 - accuracy: 1.0000
# Epoch 97/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2180 - accuracy: 0.9143
# Epoch 98/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1694 - accuracy: 0.9714
# Epoch 99/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0974 - accuracy: 1.0000
# Epoch 100/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0593 - accuracy: 1.0000
# Epoch 101/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0949 - accuracy: 0.9714
# Epoch 102/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0540 - accuracy: 1.0000
# Epoch 103/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1178 - accuracy: 0.9714
# Epoch 104/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0140 - accuracy: 1.0000
# Epoch 105/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1479 - accuracy: 0.9714
# Epoch 106/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1615 - accuracy: 0.9429
# Epoch 107/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0678 - accuracy: 1.0000
# Epoch 108/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0366 - accuracy: 1.0000
# Epoch 109/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0796 - accuracy: 1.0000
# Epoch 110/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1893 - accuracy: 0.9714
# Epoch 111/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0204 - accuracy: 1.0000
# Epoch 112/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1457 - accuracy: 0.9714
# Epoch 113/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0629 - accuracy: 1.0000
# Epoch 114/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0512 - accuracy: 1.0000
# Epoch 115/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0836 - accuracy: 0.9714
# Epoch 116/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0850 - accuracy: 0.9714
# Epoch 117/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0596 - accuracy: 1.0000
# Epoch 118/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0749 - accuracy: 0.9714
# Epoch 119/200
# 7/7 [==============================] - 0s 16ms/step - loss: 0.0547 - accuracy: 1.0000
# Epoch 120/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0530 - accuracy: 1.0000
# Epoch 121/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0247 - accuracy: 1.0000
# Epoch 122/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0712 - accuracy: 0.9714
# Epoch 123/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1340 - accuracy: 0.9429
# Epoch 124/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0474 - accuracy: 1.0000
# Epoch 125/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0531 - accuracy: 0.9714
# Epoch 126/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1199 - accuracy: 0.9714
# Epoch 127/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1281 - accuracy: 0.9429
# Epoch 128/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1056 - accuracy: 0.9714
# Epoch 129/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0876 - accuracy: 0.9714
# Epoch 130/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0926 - accuracy: 0.9714
# Epoch 131/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0401 - accuracy: 1.0000
# Epoch 132/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1331 - accuracy: 0.9714
# Epoch 133/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0568 - accuracy: 1.0000
# Epoch 134/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0217 - accuracy: 1.0000
# Epoch 135/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0718 - accuracy: 1.0000
# Epoch 136/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0959 - accuracy: 0.9714
# Epoch 137/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0227 - accuracy: 1.0000
# Epoch 138/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0633 - accuracy: 1.0000
# Epoch 139/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 140/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 141/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1191 - accuracy: 0.9714
# Epoch 142/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0308 - accuracy: 1.0000
# Epoch 143/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1108 - accuracy: 0.9714
# Epoch 144/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0225 - accuracy: 1.0000
# Epoch 145/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0690 - accuracy: 0.9714
# Epoch 146/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0212 - accuracy: 1.0000
# Epoch 147/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0576 - accuracy: 1.0000
# Epoch 148/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0690 - accuracy: 0.9714
# Epoch 149/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0353 - accuracy: 1.0000
# Epoch 150/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0334 - accuracy: 1.0000
# Epoch 151/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0367 - accuracy: 1.0000
# Epoch 152/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0391 - accuracy: 1.0000
# Epoch 153/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0583 - accuracy: 1.0000
# Epoch 154/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0729 - accuracy: 0.9714
# Epoch 155/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0875 - accuracy: 0.9714
# Epoch 156/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0709 - accuracy: 0.9714
# Epoch 157/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0300 - accuracy: 1.0000
# Epoch 158/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0422 - accuracy: 1.0000
# Epoch 159/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1179 - accuracy: 0.9714
# Epoch 160/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0403 - accuracy: 1.0000
# Epoch 161/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0383 - accuracy: 1.0000
# Epoch 162/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0368 - accuracy: 0.9714
# Epoch 163/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0257 - accuracy: 1.0000
# Epoch 164/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0866 - accuracy: 0.9714
# Epoch 165/200
# 7/7 [==============================] - 0s 28ms/step - loss: 0.0340 - accuracy: 1.0000
# Epoch 166/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0512 - accuracy: 0.9714
# Epoch 167/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0803 - accuracy: 0.9714
# Epoch 168/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0198 - accuracy: 1.0000
# Epoch 169/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 170/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 171/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0315 - accuracy: 1.0000
# Epoch 172/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0249 - accuracy: 1.0000
# Epoch 173/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0356 - accuracy: 1.0000
# Epoch 174/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0867 - accuracy: 0.9429
# Epoch 175/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0470 - accuracy: 0.9714
# Epoch 176/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0427 - accuracy: 1.0000
# Epoch 177/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0808 - accuracy: 0.9714
# Epoch 178/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0177 - accuracy: 1.0000
# Epoch 179/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0870 - accuracy: 0.9429
# Epoch 180/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.1054 - accuracy: 0.9714
# Epoch 181/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0381 - accuracy: 1.0000
# Epoch 182/200
# 7/7 [==============================] - 0s 15ms/step - loss: 0.0282 - accuracy: 1.0000
# Epoch 183/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 184/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0741 - accuracy: 0.9429
# Epoch 185/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0287 - accuracy: 1.0000
# Epoch 186/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0138 - accuracy: 1.0000
# Epoch 187/200
# 7/7 [==============================] - 0s 31ms/step - loss: 0.0324 - accuracy: 1.0000
# Epoch 188/200
# 7/7 [==============================] - 0s 13ms/step - loss: 0.0440 - accuracy: 1.0000
# Epoch 189/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 190/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0507 - accuracy: 0.9714
# Epoch 191/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0278 - accuracy: 1.0000
# Epoch 192/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0191 - accuracy: 1.0000
# Epoch 193/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0747 - accuracy: 0.9714
# Epoch 194/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0146 - accuracy: 1.0000
# Epoch 195/200
# 7/7 [==============================] - 0s 11ms/step - loss: 0.0832 - accuracy: 0.9714
# Epoch 196/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 197/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0197 - accuracy: 1.0000
# Epoch 198/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0139 - accuracy: 1.0000
# Epoch 199/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0183 - accuracy: 1.0000
# Epoch 200/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0640 - accuracy: 0.9714

# %%
# Print the training accuracy
training_accuracy = history.history['accuracy'][-1]
print(f'Training Accuracy: {training_accuracy * 100:.2f}%')
# Out:
# Training Accuracy: 97.14%

# %%
import pickle

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print(f"found in bag: {w}")
    return np.array(bag)

def predict_class(sentence, model):
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def get_response(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints = predict_class(text, model)
    res = get_response(ints, intents)
    return res

# %%
import tkinter as tk
from tkinter import *

def send():
    msg = EntryBox.get("1.0", 'end-1c').strip()
    EntryBox.delete("0.0", END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Chatbot")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana", 12, 'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b", fg='#ffffff',
                    command=send)

EntryBox = Text(base, bd=0, bg="white", width="29", height="5", font="Arial")
EntryBox.bind("<Return>", lambda event: send())

scrollbar.place(x=376, y=6, height=386)
ChatLog.place(x=6, y=6, height=386, width=370)
EntryBox.place(x=6, y=401, height=90, width=265)
SendButton.place(x=275, y=401, height=90, width=125)

base.mainloop()
# Out:
# 1/1 [==============================] - 0s 96ms/step
# 1/1 [==============================] - 0s 31ms/step
# 1/1 [==============================] - 0s 31ms/step
