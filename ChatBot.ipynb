# %%
import json
import numpy as np
import random
import nltk
from nltk.stem import WordNetLemmatizer
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.optimizers import SGD

nltk.download('punkt')
nltk.download('wordnet')

lemmatizer = WordNetLemmatizer()

# Load intents file
with open('intents.json') as file:
    intents = json.load(file)

words = []
classes = []
documents = []
ignore_words = ['?', '!', '.']

# Preprocess data
for intent in intents['intents']:
    for pattern in intent['patterns']:
        word_list = nltk.word_tokenize(pattern)
        words.extend(word_list)
        documents.append((word_list, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(w.lower()) for w in words if w not in ignore_words]
words = sorted(list(set(words)))

classes = sorted(list(set(classes)))

training = []
output_empty = [0] * len(classes)

for doc in documents:
    bag = []
    pattern_words = doc[0]
    pattern_words = [lemmatizer.lemmatize(word.lower()) for word in pattern_words]
    for word in words:
        bag.append(1) if word in pattern_words else bag.append(0)
    output_row = list(output_empty)
    output_row[classes.index(doc[1])] = 1
    training.append([bag, output_row])

random.shuffle(training)
training = np.array(training, dtype=object)

train_x = np.array(list(training[:, 0]), dtype=np.float32)
train_y = np.array(list(training[:, 1]), dtype=np.float32)
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\parth\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\parth\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
model = Sequential()
model.add(Dense(128, input_shape=(len(train_x[0]),), activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(len(train_y[0]), activation='softmax'))

sgd = SGD(learning_rate=0.01, decay=1e-6, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

history = model.fit(train_x, train_y, epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5')
# Out:
# Epoch 1/200
# 7/7 [==============================] - 2s 5ms/step - loss: 2.3927 - accuracy: 0.0571
# Epoch 2/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.3011 - accuracy: 0.0857
# Epoch 3/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.2807 - accuracy: 0.1143
# Epoch 4/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.2593 - accuracy: 0.1714
# Epoch 5/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.2246 - accuracy: 0.2000
# Epoch 6/200
# 7/7 [==============================] - 0s 6ms/step - loss: 2.1942 - accuracy: 0.2286
# Epoch 7/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.1246 - accuracy: 0.3714
# Epoch 8/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0950 - accuracy: 0.3429
# Epoch 9/200
# 7/7 [==============================] - 0s 5ms/step - loss: 2.0480 - accuracy: 0.3714
# Epoch 10/200
# 7/7 [==============================] - 0s 7ms/step - loss: 2.0735 - accuracy: 0.4000
# Epoch 11/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.9240 - accuracy: 0.3143
# Epoch 12/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.7675 - accuracy: 0.6857
# Epoch 13/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7451 - accuracy: 0.6000
# Epoch 14/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7617 - accuracy: 0.4286
# Epoch 15/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.7472 - accuracy: 0.4286
# Epoch 16/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.5738 - accuracy: 0.5143
# Epoch 17/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3948 - accuracy: 0.5714
# Epoch 18/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.5895 - accuracy: 0.5714
# Epoch 19/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.4758 - accuracy: 0.5143
# Epoch 20/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3560 - accuracy: 0.6286
# Epoch 21/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1814 - accuracy: 0.6571
# Epoch 22/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.2751 - accuracy: 0.5714
# Epoch 23/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.3269 - accuracy: 0.6286
# Epoch 24/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.1388 - accuracy: 0.6286
# Epoch 25/200
# 7/7 [==============================] - 0s 4ms/step - loss: 1.1218 - accuracy: 0.6857
# Epoch 26/200
# 7/7 [==============================] - 0s 5ms/step - loss: 1.0294 - accuracy: 0.7143
# Epoch 27/200
# 7/7 [==============================] - 0s 6ms/step - loss: 1.0118 - accuracy: 0.7143
# Epoch 28/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.8502 - accuracy: 0.8000
# Epoch 29/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8111 - accuracy: 0.8857
# Epoch 30/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.8463 - accuracy: 0.8000
# Epoch 31/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6184 - accuracy: 0.8857
# Epoch 32/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6917 - accuracy: 0.8286
# Epoch 33/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.7170 - accuracy: 0.8000
# Epoch 34/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5061 - accuracy: 0.9429
# Epoch 35/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6624 - accuracy: 0.7714
# Epoch 36/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4878 - accuracy: 0.8286
# Epoch 37/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.4838 - accuracy: 0.9143
# Epoch 38/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6793 - accuracy: 0.8857
# Epoch 39/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3106 - accuracy: 0.9714
# Epoch 40/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4704 - accuracy: 0.8857
# Epoch 41/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.4275 - accuracy: 0.9143
# Epoch 42/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.4835 - accuracy: 0.8000
# Epoch 43/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3226 - accuracy: 0.8857
# Epoch 44/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.3595 - accuracy: 0.9714
# Epoch 45/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3236 - accuracy: 0.9143
# Epoch 46/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3262 - accuracy: 0.9429
# Epoch 47/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.5437 - accuracy: 0.8286
# Epoch 48/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2325 - accuracy: 0.9143
# Epoch 49/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2862 - accuracy: 0.9429
# Epoch 50/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3679 - accuracy: 0.8857
# Epoch 51/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1739 - accuracy: 0.9714
# Epoch 52/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2274 - accuracy: 0.9429
# Epoch 53/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2567 - accuracy: 1.0000
# Epoch 54/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2512 - accuracy: 1.0000
# Epoch 55/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1877 - accuracy: 0.9714
# Epoch 56/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.2223 - accuracy: 0.9143
# Epoch 57/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2362 - accuracy: 0.9714
# Epoch 58/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2050 - accuracy: 0.9714
# Epoch 59/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1450 - accuracy: 1.0000
# Epoch 60/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1819 - accuracy: 0.9714
# Epoch 61/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1707 - accuracy: 0.9429
# Epoch 62/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1945 - accuracy: 0.9143
# Epoch 63/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2071 - accuracy: 0.9714
# Epoch 64/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2251 - accuracy: 0.9429
# Epoch 65/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1886 - accuracy: 0.9429
# Epoch 66/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1985 - accuracy: 1.0000
# Epoch 67/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1902 - accuracy: 0.9714
# Epoch 68/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2886 - accuracy: 0.8857
# Epoch 69/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1308 - accuracy: 0.9714
# Epoch 70/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.3158 - accuracy: 0.9143
# Epoch 71/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0795 - accuracy: 1.0000
# Epoch 72/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1035 - accuracy: 0.9714
# Epoch 73/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.1741 - accuracy: 0.9714
# Epoch 74/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1426 - accuracy: 0.9429
# Epoch 75/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1742 - accuracy: 1.0000
# Epoch 76/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1059 - accuracy: 1.0000
# Epoch 77/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2016 - accuracy: 0.9143
# Epoch 78/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0989 - accuracy: 1.0000
# Epoch 79/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.3381 - accuracy: 0.9143
# Epoch 80/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1198 - accuracy: 0.9429
# Epoch 81/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.2828 - accuracy: 0.8857
# Epoch 82/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1454 - accuracy: 0.9714
# Epoch 83/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1172 - accuracy: 0.9714
# Epoch 84/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1362 - accuracy: 0.9714
# Epoch 85/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1385 - accuracy: 0.9714
# Epoch 86/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1272 - accuracy: 1.0000
# Epoch 87/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1904 - accuracy: 0.9714
# Epoch 88/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1219 - accuracy: 0.9714
# Epoch 89/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1009 - accuracy: 1.0000
# Epoch 90/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.1030 - accuracy: 1.0000
# Epoch 91/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1326 - accuracy: 0.9714
# Epoch 92/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1380 - accuracy: 0.9429
# Epoch 93/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.2551 - accuracy: 0.9143
# Epoch 94/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1815 - accuracy: 0.9143
# Epoch 95/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 96/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0612 - accuracy: 1.0000
# Epoch 97/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0864 - accuracy: 1.0000
# Epoch 98/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1413 - accuracy: 0.9429
# Epoch 99/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 100/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0988 - accuracy: 0.9714
# Epoch 101/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0959 - accuracy: 0.9714
# Epoch 102/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0760 - accuracy: 1.0000
# Epoch 103/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0871 - accuracy: 1.0000
# Epoch 104/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1754 - accuracy: 0.9429
# Epoch 105/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0388 - accuracy: 1.0000
# Epoch 106/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1786 - accuracy: 0.9429
# Epoch 107/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0559 - accuracy: 1.0000
# Epoch 108/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0798 - accuracy: 1.0000
# Epoch 109/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0682 - accuracy: 0.9714
# Epoch 110/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0528 - accuracy: 1.0000
# Epoch 111/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1567 - accuracy: 0.9429
# Epoch 112/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0474 - accuracy: 0.9714
# Epoch 113/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0914 - accuracy: 0.9714
# Epoch 114/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0700 - accuracy: 1.0000
# Epoch 115/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1384 - accuracy: 0.9714
# Epoch 116/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0865 - accuracy: 1.0000
# Epoch 117/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0150 - accuracy: 1.0000
# Epoch 118/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1640 - accuracy: 0.9143
# Epoch 119/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0756 - accuracy: 1.0000
# Epoch 120/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1434 - accuracy: 0.9714
# Epoch 121/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1011 - accuracy: 0.9714
# Epoch 122/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0880 - accuracy: 1.0000
# Epoch 123/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0819 - accuracy: 1.0000
# Epoch 124/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0594 - accuracy: 1.0000
# Epoch 125/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0795 - accuracy: 0.9714
# Epoch 126/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0684 - accuracy: 1.0000
# Epoch 127/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0880 - accuracy: 1.0000
# Epoch 128/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0306 - accuracy: 1.0000
# Epoch 129/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.1569 - accuracy: 0.9429
# Epoch 130/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0224 - accuracy: 1.0000
# Epoch 131/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0743 - accuracy: 1.0000
# Epoch 132/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0549 - accuracy: 0.9714
# Epoch 133/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0728 - accuracy: 1.0000
# Epoch 134/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0397 - accuracy: 1.0000
# Epoch 135/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0270 - accuracy: 1.0000
# Epoch 136/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0904 - accuracy: 0.9714
# Epoch 137/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0436 - accuracy: 1.0000
# Epoch 138/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.0380 - accuracy: 1.0000
# Epoch 139/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1310 - accuracy: 0.9143
# Epoch 140/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0384 - accuracy: 1.0000
# Epoch 141/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0927 - accuracy: 0.9714
# Epoch 142/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0481 - accuracy: 0.9714
# Epoch 143/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0101 - accuracy: 1.0000
# Epoch 144/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0621 - accuracy: 1.0000
# Epoch 145/200
# 7/7 [==============================] - 0s 18ms/step - loss: 0.0394 - accuracy: 1.0000
# Epoch 146/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.1339 - accuracy: 0.9429
# Epoch 147/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.0475 - accuracy: 1.0000
# Epoch 148/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1519 - accuracy: 0.9429
# Epoch 149/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0493 - accuracy: 0.9714
# Epoch 150/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.1570 - accuracy: 0.9714
# Epoch 151/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0347 - accuracy: 1.0000
# Epoch 152/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0504 - accuracy: 1.0000
# Epoch 153/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0331 - accuracy: 1.0000
# Epoch 154/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0466 - accuracy: 1.0000
# Epoch 155/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1540 - accuracy: 0.9429
# Epoch 156/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0346 - accuracy: 1.0000
# Epoch 157/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0305 - accuracy: 1.0000
# Epoch 158/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0506 - accuracy: 1.0000
# Epoch 159/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1077 - accuracy: 0.9429
# Epoch 160/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0708 - accuracy: 1.0000
# Epoch 161/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0437 - accuracy: 0.9714
# Epoch 162/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0430 - accuracy: 1.0000
# Epoch 163/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0184 - accuracy: 1.0000
# Epoch 164/200
# 7/7 [==============================] - 0s 20ms/step - loss: 0.0780 - accuracy: 0.9714
# Epoch 165/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0772 - accuracy: 0.9714
# Epoch 166/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0384 - accuracy: 0.9714
# Epoch 167/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0456 - accuracy: 1.0000
# Epoch 168/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0716 - accuracy: 1.0000
# Epoch 169/200
# 7/7 [==============================] - 0s 10ms/step - loss: 0.0170 - accuracy: 1.0000
# Epoch 170/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 171/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0574 - accuracy: 0.9714
# Epoch 172/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0151 - accuracy: 1.0000
# Epoch 173/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0238 - accuracy: 1.0000
# Epoch 174/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0776 - accuracy: 0.9714
# Epoch 175/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0235 - accuracy: 1.0000
# Epoch 176/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0716 - accuracy: 0.9714
# Epoch 177/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0482 - accuracy: 1.0000
# Epoch 178/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0276 - accuracy: 1.0000
# Epoch 179/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.1045 - accuracy: 0.9429
# Epoch 180/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0175 - accuracy: 1.0000
# Epoch 181/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0332 - accuracy: 1.0000
# Epoch 182/200
# 7/7 [==============================] - 0s 19ms/step - loss: 0.0145 - accuracy: 1.0000
# Epoch 183/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0215 - accuracy: 1.0000
# Epoch 184/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0538 - accuracy: 1.0000
# Epoch 185/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0143 - accuracy: 1.0000
# Epoch 186/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0237 - accuracy: 1.0000
# Epoch 187/200
# 7/7 [==============================] - 0s 7ms/step - loss: 0.0097 - accuracy: 1.0000
# Epoch 188/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0248 - accuracy: 1.0000
# Epoch 189/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0274 - accuracy: 1.0000
# Epoch 190/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0400 - accuracy: 1.0000
# Epoch 191/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 192/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0104 - accuracy: 1.0000
# Epoch 193/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0457 - accuracy: 1.0000
# Epoch 194/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0275 - accuracy: 1.0000
# Epoch 195/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0236 - accuracy: 1.0000
# Epoch 196/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0253 - accuracy: 1.0000
# Epoch 197/200
# 7/7 [==============================] - 0s 8ms/step - loss: 0.0425 - accuracy: 0.9714
# Epoch 198/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0518 - accuracy: 1.0000
# Epoch 199/200
# 7/7 [==============================] - 0s 22ms/step - loss: 0.0165 - accuracy: 1.0000
# Epoch 200/200
# 7/7 [==============================] - 0s 9ms/step - loss: 0.0410 - accuracy: 1.0000

# %%
# Print the training accuracy
training_accuracy = history.history['accuracy'][-1]
print(f'Training Accuracy: {training_accuracy * 100:.2f}%')
# Out:
# Training Accuracy: 100.00%

# %%
import pickle

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word.lower()) for word in sentence_words]
    return sentence_words

def bow(sentence, words, show_details=True):
    sentence_words = clean_up_sentence(sentence)
    bag = [0]*len(words)
    for s in sentence_words:
        for i, w in enumerate(words):
            if w == s:
                bag[i] = 1
                if show_details:
                    print(f"found in bag: {w}")
    return np.array(bag)

def predict_class(sentence, model):
    p = bow(sentence, words, show_details=False)
    res = model.predict(np.array([p]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]
    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({"intent": classes[r[0]], "probability": str(r[1])})
    return return_list

def get_response(ints, intents_json):
    tag = ints[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice(i['responses'])
            break
    return result

def chatbot_response(text):
    ints = predict_class(text, model)
    res = get_response(ints, intents)
    return res

# %%
import tkinter as tk
from tkinter import *

def send():
    msg = EntryBox.get("1.0", 'end-1c').strip()
    EntryBox.delete("0.0", END)
    if msg != '':
        ChatLog.config(state=NORMAL)
        ChatLog.insert(END, "You: " + msg + '\n\n')
        ChatLog.config(foreground="#442265", font=("Verdana", 12))
        res = chatbot_response(msg)
        ChatLog.insert(END, "Bot: " + res + '\n\n')
        ChatLog.config(state=DISABLED)
        ChatLog.yview(END)

base = Tk()
base.title("Chatbot")
base.geometry("400x500")
base.resizable(width=FALSE, height=FALSE)

ChatLog = Text(base, bd=0, bg="white", height="8", width="50", font="Arial",)
ChatLog.config(state=DISABLED)

scrollbar = Scrollbar(base, command=ChatLog.yview, cursor="heart")
ChatLog['yscrollcommand'] = scrollbar.set

SendButton = Button(base, font=("Verdana", 12, 'bold'), text="Send", width="12", height=5,
                    bd=0, bg="#32de97", activebackground="#3c9d9b", fg='#ffffff',
                    command=send)

EntryBox = Text(base, bd=0, bg="white", width="29", height="5", font="Arial")
EntryBox.bind("<Return>", lambda event: send())

scrollbar.place(x=376, y=6, height=386)
ChatLog.place(x=6, y=6, height=386, width=370)
EntryBox.place(x=6, y=401, height=90, width=265)
SendButton.place(x=275, y=401, height=90, width=125)

base.mainloop()
# Out:
# 1/1 [==============================] - 0s 109ms/step
